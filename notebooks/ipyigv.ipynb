# %%
import ipyigv as igv
from ipywidgets.widgets.trait_types import InstanceDict
from ipyigv.options import ReferenceGenome, Track
from ipywidgets import Output

# %% [markdown]
# ## Initializing the browser

# %%
genomeDict = igv.PUBLIC_GENOMES.hg38

# %%
genome = ReferenceGenome(**genomeDict)

# %%
browser = igv.IgvBrowser(genome=genome)

# %%
browser
# Out:
# IgvBrowser(genome=ReferenceGenome(cytobandURL='https://s3.dualstack.us-east-1.amazonaws.com/igv.org.genomes/hg…

# %% [markdown]
# ## Adding or removing a track

# %%
trackDict = {
  'name': 'Refseq Genes',
  'format': 'refgene',
  'url': 'https://s3.dualstack.us-east-1.amazonaws.com/igv.org.genomes/hg38/refGene.txt.gz',
  'indexed': False,
  'visibilityWindow': -1,
  'removable': False,
  'order': 1000000
}

# %%
oneMoreTrack = Track(**trackDict)

# %%
browser.add_track(oneMoreTrack)

# %%
browser.remove_track(oneMoreTrack)

# %% [markdown]
# ## Adding a Region of Interest

# %%
roiDict = {
  'name': 'ROI set 1',
  'url': 'https://s3.amazonaws.com/igv.org.test/data/roi/roi_bed_1.bed',
  'indexed': False,
  'color': "rgba(68, 134, 247, 0.25)"
}

# %%
roi = igv.options.AnnotationTrack(**roiDict)

# %%
browser.add_roi(roi)

# %% [markdown]
# ## Searching

# %%
browser.search('chr3:1-190,100,300')
# Out:
# Search completed. Check the widget instance for results.

# %% [markdown]
# ## Getting the browser configuration
# We need to output the configuration in `browser.out`, which is an `Output` widget

# %%
browser.dump_json()
# Out:
# Dumping browser configuration to browser.out

# %%
browser.out
# Out:
# Output(outputs=({'output_type': 'stream', 'text': "{'version': '2.7.0', 'reference': {'id': 'hg38', 'name': 'H…

# %% [markdown]
# ## Charging local files
# NB: `igv.js` tries to load a file `undefined.fai` which causes an error. Maybe due to the use of `localhost:8000` -- activate it with `python -m http.server` in your files directory.

# %%
genome2 = {
 'name': 'Example chr6p',
 'fastaURL': 'http://localhost:8000/chr6p.fa',
 'indexURL': 'http://localhost:8000/chr6p.fa.fai',
}

# %%
pgf6p_on_chr6p_track = {
  'name': 'PGF 6p on chr6p',
  'format': 'refgene',
  'url': 'http://localhost:8000/PGF_6p_on_chr6p.bam',
  'indexURL': 'http://localhost:8000/PGF_6p_on_chr6p.bai',
}

# %%
browser2 = igv.IgvBrowser(genome=ReferenceGenome(**genome2))

# %%
browser2
# Out:
# IgvBrowser(genome=ReferenceGenome(fastaURL='http://localhost:8000/chr6p.fa', indexURL='http://localhost:8000/c…

# %%
import urllib.request

# %%
url = urllib.request.urlopen('http://localhost:8000/chr6p.fa.fai')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/mambaforge/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~/mambaforge/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~/mambaforge/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ~/mambaforge/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# ~/mambaforge/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# ~/mambaforge/lib/python3.8/http/client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# ~/mambaforge/lib/python3.8/http/client.py in connect(self)
#     920         """Connect to the host and port specified in __init__."""
# --> 921         self.sock = self._create_connection(
#     922             (self.host,self.port), self.timeout, self.source_address)
#
# ~/mambaforge/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# ~/mambaforge/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-21-0ba9ddfa92c7> in <module>
# ----> 1 url = urllib.request.urlopen('http://localhost:8000/chr6p.fa.fai')
#
# ~/mambaforge/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/mambaforge/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/mambaforge/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~/mambaforge/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/mambaforge/lib/python3.8/urllib/request.py in http_open(self, req)
#    1377
#    1378     def http_open(self, req):
# -> 1379         return self.do_open(http.client.HTTPConnection, req)
#    1380
#    1381     http_request = AbstractHTTPHandler.do_request_
#
# ~/mambaforge/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#    1352             except OSError as err: # timeout error
# -> 1353                 raise URLError(err)
#    1354             r = h.getresponse()
#    1355         except:
#
# URLError: <urlopen error [Errno 111] Connection refused>

# %%
print(url.read(100).decode('utf-8'))
